# %%
data2 = []

cases2 = [
    {
        "name": "title:Python",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["Python"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:Python3",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["Python"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:Python3.12",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["Python"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:Go",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["Go"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:Golang",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["Go"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "document:functional",
        "tp": 9, "fp": 8, "fn": 4,
        "tp_langs": ["Haskell", "Scala", "Elixir", "Python", "Rust", "Lua", "JavaScript", "Go", "R"],
        "fp_langs": ["Groovy", "C#", "Swift", "Kotlin", "Ruby", "Java", "Assembly language", "PHP"],
        "fn_langs": ["MATLAB", "Zig", "TypeScript", "C++"]
    },
    {
        "name": "document:declarative",
        "tp": 9, "fp": 8, "fn": 4,
        "tp_langs": ["Rust", "Haskell", "Scala", "Elixir", "Python", "Lua", "JavaScript", "Go", "R"],
        "fp_langs": ["Groovy", "Swift", "Assembly language", "C#", "Kotlin", "Ruby", "Java", "C"],
        "fn_langs": ["MATLAB", "Zig", "TypeScript", "C++"]
    },
    {
        "name": "document:object-oriented",
        "tp": 7, "fp": 3, "fn": 10,
        "tp_langs": ["Groovy", "Ruby", "JavaScript", "Python", "Java", "Kotlin", "Swift"],
        "fp_langs": ["Scala", "Assembly language", "C"],
        "fn_langs": ["C#", "PHP", "PowerShell", "Dart", "Rust", "Zig", "TypeScript", "C++", "Lua", "Go"]
    },
    {
        "name": "document:imperative",
        "tp": 4, "fp": 3, "fn": 13,
        "tp_langs": ["Go", "PowerShell", "C#", "Python"],
        "fp_langs": ["C", "Scala", "Elixir"],
        "fn_langs": ["Java", "PHP", "Dart", "Kotlin", "Groovy", "Ruby", "Swift", "Rust", "Zig", "JavaScript", "TypeScript", "C++", "Lua"]
    },
    {
        "name": "title:C#",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["C#"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:C Sharp",
        "tp": 1, "fp": 0, "fn": 0,
        "tp_langs": ["C#"],
        "fp_langs": [],
        "fn_langs": []
    },
    {
        "name": "title:C++",
        "tp": 1, "fp": 0, "fn": 1,
        "tp_langs": ["C++"],
        "fp_langs": [],
        "fn_langs": ["C"]
    },
    {
        "name": "title:C plus plus",
        "tp": 1, "fp": 0, "fn": 1,
        "tp_langs": ["C++"],
        "fp_langs": [],
        "fn_langs": ["C"]
    },
    {
        "name": "document:\"JavaScript framework\"",
        "tp": 2, "fp": 1, "fn": 0,
        "tp_langs": ["JavaScript", "TypeScript"],
        "fp_langs": ["Dart"],
        "fn_langs": []
    },
    {
        "name": "document:\"Javascrit framework\"",
        "tp": 0, "fp": 0, "fn": 2,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["JavaScript", "TypeScript"]
    },
    {
        "name": "document:\"most modern programming languages\"",
        "tp": 1, "fp": 0, "fn": 7,
        "tp_langs": ["Swift"],
        "fp_langs": [],
        "fn_langs": ["Zig", "Rust", "Kotlin", "TypeScript", "Elixir", "Dart", "Go"]
    },
    {
        "name": "document:\"modern programming languages\"",
        "tp": 1, "fp": 0, "fn": 7,
        "tp_langs": ["Swift"],
        "fp_langs": [],
        "fn_langs": ["Zig", "Rust", "Kotlin", "TypeScript", "Elixir", "Dart", "Go"]
    },
    {
        "name": "document:\"trendy programming languages\"",
        "tp": 1, "fp": 0, "fn": 7,
        "tp_langs": ["Swift"],
        "fp_langs": [],
        "fn_langs": ["Zig", "Rust", "Kotlin", "TypeScript", "Elixir", "Dart", "Go"]
    },
    {
        "name": "document:\"What is the best programming language for web development\"",
        "tp": 0, "fp": 0, "fn": 2,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["JavaScript", "TypeScript"]
    },
    {
        "name": "document:\"Top programming languages for web development\"",
        "tp": 0, "fp": 0, "fn": 2,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["JavaScript", "TypeScript"]
    },
    {
        "name": "document:\"Best coding languages for building websites\"",
        "tp": 0, "fp": 0, "fn": 2,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["JavaScript", "TypeScript"]
    },
    {
        "name": "document:\"Best programming language for web development\"",
        "tp": 0, "fp": 0, "fn": 2,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["JavaScript", "TypeScript"]
    },
    {
        "name": "document:\"Best systems programming language for safety\"",
        "tp": 0, "fp": 0, "fn": 4,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["Rust", "Zig", "Swift", "Go"]
    },
    {
        "name": "document:\"What is a memory-safe programming language\"",
        "tp": 1, "fp": 0, "fn": 2,
        "tp_langs": ["Rust"],
        "fp_langs": [],
        "fn_langs": ["Zig", "Swift"]
    },
    {
        "name": "document:\"Most secure programming language\"",
        "tp": 0, "fp": 0, "fn": 1,
        "tp_langs": [],
        "fp_langs": [],
        "fn_langs": ["Rust"]
    },
]

for case in cases2:
    s1_pre = precision(case["tp"], case["fp"])
    s1_rec = recall(case["tp"], case["fn"])
    s1_f1 = f1_score(s1_pre, s1_rec)
    case_out = {
        "name": case["name"],
        "s1_pre": s1_pre,
        "s1_rec": s1_rec,
        "s1_f1": s1_f1,
        "tp": case["tp"],
        "fp": case["fp"],
        "fn": case["fn"],
        "tp_langs": case["tp_langs"],
        "fp_langs": case["fp_langs"],
        "fn_langs": case["fn_langs"],
    }
    data2.append(case_out)
    print(f"[{case['name']}] F1-Score {s1_f1:.2f}")
