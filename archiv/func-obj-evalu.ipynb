# %%
    {
        "name": "document:functional",
        "expected_langs": [
            {"lang": "Haskell",      "rank": 1},
            {"lang": "Scala",        "rank": 2},
            {"lang": "Elixir",       "rank": 3},
            {"lang": "R",            "rank": 4},
            {"lang": "Rust",         "rank": 5},
            {"lang": "Python",       "rank": 6},
            {"lang": "C++",          "rank": 7},
            {"lang": "TypeScript",   "rank": 8},
            {"lang": "JavaScript",   "rank": 9},
            {"lang": "Lua",          "rank": 10},
            {"lang": "Go",           "rank": 11},
            {"lang": "Zig",          "rank": 12},
            {"lang": "MATLAB",       "rank": 13}
        ]
    },
    {
        "name": "document:declarative",
        "expected_langs": [
            {"lang": "Haskell",      "rank": 1},
            {"lang": "Scala",        "rank": 2},
            {"lang": "Elixir",       "rank": 3},
            {"lang": "R",            "rank": 4},
            {"lang": "Rust",         "rank": 5},
            {"lang": "Python",       "rank": 6},
            {"lang": "C++",          "rank": 7},
            {"lang": "TypeScript",   "rank": 8},
            {"lang": "JavaScript",   "rank": 9},
            {"lang": "Lua",          "rank": 10},
            {"lang": "Go",           "rank": 11},
            {"lang": "Zig",          "rank": 12},
            {"lang": "MATLAB",       "rank": 13}
        ]
    },
    {
        "name": "document:object-oriented",
        "expected_langs": [
            {"lang": "Java",         "rank": 1},
            {"lang": "C#",           "rank": 2},
            {"lang": "Python",       "rank": 3},
            {"lang": "Ruby",         "rank": 4},
            {"lang": "Kotlin",       "rank": 5},
            {"lang": "Groovy",       "rank": 6},
            {"lang": "Swift",        "rank": 7},
            {"lang": "PHP",          "rank": 8},
            {"lang": "JavaScript",   "rank": 9},
            {"lang": "TypeScript",   "rank": 10},
            {"lang": "Go",           "rank": 11},
            {"lang": "Dart",         "rank": 12},
            {"lang": "Lua",          "rank": 13},
            {"lang": "Rust",         "rank": 14},
            {"lang": "PowerShell",   "rank": 15},
            {"lang": "C++",          "rank": 16},
            {"lang": "Zig",          "rank": 17}
        ]
    },
    {
        "name": "document:imperative",
        "expected_langs": [
            {"lang": "Java",         "rank": 1},
            {"lang": "C#",           "rank": 2},
            {"lang": "Python",       "rank": 3},
            {"lang": "Ruby",         "rank": 4},
            {"lang": "Kotlin",       "rank": 5},
            {"lang": "Groovy",       "rank": 6},
            {"lang": "Swift",        "rank": 7},
            {"lang": "PHP",          "rank": 8},
            {"lang": "JavaScript",   "rank": 9},
            {"lang": "TypeScript",   "rank": 10},
            {"lang": "Go",           "rank": 11},
            {"lang": "Dart",         "rank": 12},
            {"lang": "Lua",          "rank": 13},
            {"lang": "Rust",         "rank": 14},
            {"lang": "PowerShell",   "rank": 15},
            {"lang": "C++",          "rank": 16},
            {"lang": "Zig",          "rank": 17}
        ]
    },
