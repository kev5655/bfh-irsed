# %%
data3 = []

name = "title:Python"

TP = 1  # True Positives = Richtige Dokumente gefunden (Python)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:Python3"

TP = 1  # True Positives = Richtige Dokumente gefunden (Python)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:Python3.12"

TP = 1  # True Positives = Richtige Dokumente gefunden (Python)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:Go"

TP = 1  # True Positives = Richtige Dokumente gefunden (Go)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")


name = "title:Golang"

TP = 1  # True Positives = Richtige Dokumente gefunden (Go)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")


# Elixir, Haskell, R, Scala, MATLAB
# Rust, Zig, Python, JavaScript, TypeScript, C++, Lua, Go
# Java, C#, PHP, PowerShell, Dart, Kotlin, Groovy, Ruby, Swift

name = "document:functional"

# True Positives = Richtige Dokumente gefunden (Haskell, Scala, Elixir, Python, Rust, Lua, JavaScript)
TP = 7
# False Positives = Gefundene, aber falsche Dokumente (Groovy, C#, Swift)
FP = 3
# False Negatives = Nicht gefundene, aber relevante Dokumente (R, MATLAB, Zig, TypeScript, C++, Go)
FN = 6

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:declarative"

# True Positives = Richtige Dokumente gefunden (Haskell, Scala, Elixir, Python, Rust, Lua, JavaScript)
TP = 7
# False Positives = Gefundene, aber falsche Dokumente (Groovy, C#, Swift)
FP = 3
# False Negatives = Nicht gefundene, aber relevante Dokumente (R, MATLAB, Zig, TypeScript, C++, Go)
FN = 6

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

# Java, C#, PHP, PowerShell, Dart, Kotlin, Groovy, Ruby, Swift
# Rust, Zig, Python, JavaScript, TypeScript, C++, Lua, Go
# Elixir, Haskell, R, Scala, MATLAB

name = "document:object-oriented"

# True Positives = Richtige Dokumente gefunden (Groovy, Ruby, JavaScript, Python, Java, Kotlin, Swift)
TP = 7
# False Positives = Gefundene, aber falsche Dokumente (Scala, Assembly language, C)
FP = 3
# False Negatives = Nicht gefundene, aber relevante Dokumente (C#, PHP, PowerShell, Dart, Rust, Zig, TypeScript, C++, Lua, Go)
FN = 10

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:imperative"

# True Positives = Richtige Dokumente gefunden (Go, PowerShell, C#, Python)
TP = 4
# False Positives = Gefundene, aber falsche Dokumente (C, Scala, Elixir)
FP = 3
# False Negatives = Nicht gefundene, aber relevante Dokumente (Java, PHP, Dart, Kotlin, Groovy, Ruby, Swift, Rust, Zig, JavaScript, TypeScript, C++, Lua)
FN = 13

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")


name = "title:C#"

TP = 1  # True Positives = Richtige Dokumente gefunden (C#)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:C Sharp"

TP = 1  # True Positives = Richtige Dokumente gefunden (C#)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:C++"

TP = 1  # True Positives = Richtige Dokumente gefunden (C++)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 1  # False Negatives = Nicht gefundene, aber relevante Dokumente (C)

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "title:C plus plus"

TP = 1  # True Positives = Richtige Dokumente gefunden (C++)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 1  # False Negatives = Nicht gefundene, aber relevante Dokumente (C)

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")


name = "document:\"JavaScript framework\""

TP = 2  # True Positives = Richtige Dokumente gefunden (JavaScript, TypeScript)
FP = 1  # False Positives = Gefundene, aber falsche Dokumente (Dart)
FN = 0  # False Negatives = Nicht gefundene, aber relevante Dokumente

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Javascrit framework\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (JavaScript, TypeScript)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"most modern programming languages\""

TP = 1  # True Positives = Richtige Dokumente gefunden (Swift)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (Zig, Rust, Kotlin, TypeScript, Elixir, Dart, Go)
FN = 7

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"modern programming languages\""

TP = 1  # True Positives = Richtige Dokumente gefunden (Swift)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (Zig, Rust, Kotlin, TypeScript, Elixir, Dart, Go)
FN = 7

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"trendy programming languages\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (Zig, Rust, Kotlin, TypeScript, Elixir, Dart, Swift, Go)
FN = 8

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"What is the best programming language for web development\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (JavaScript, TypeScript)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Top programming languages for web development\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (JavaScript, TypeScript)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Best coding languages for building websites\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente  (JavaScript, TypeScript)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Best programming language for web development\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (JavaScript, TypeScript)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Best systems programming language for safety\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (Rust, Zig, Swift, Go)
FN = 4

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"What is a memory-safe programming language\""

TP = 1  # True Positives = Richtige Dokumente gefunden (Rust)
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
# False Negatives = Nicht gefundene, aber relevante Dokumente (Zig, Swift)
FN = 2

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")

name = "document:\"Most secure programming language\""

TP = 0  # True Positives = Richtige Dokumente gefunden
FP = 0  # False Positives = Gefundene, aber falsche Dokumente
FN = 1  # False Negatives = Nicht gefundene, aber relevante Dokumente (Rust)

s1_pre = precision(TP, FP)
s1_rec = recall(TP, FN)
s1_f1 = f1_score(s1_pre, s1_rec)
data3.append({"name": name, "s1_pre": s1_pre, "s1_rec": s1_rec,
             "s1_f1": s1_f1, "tp": TP, "fp": FP, "fn": FN})
print(f"[{name}] F1-Score {s1_f1:.2f}")
